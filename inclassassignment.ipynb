# %% [markdown]
# <a href="https://colab.research.google.com/github/sdp154-dot/bte320/blob/main/inclassassignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter Sales ($): "))
rate = float(input("Enter Tax Rate (%): "))

cogs = sales * 0.4
gross_profit = sales - cogs
taxes = rate * gross_profit / 100
net = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
print(f"Taxes: {taxes}$")
print(f"Net Income: {net}$")
# Out:
# Enter Sales ($): 12000
# Enter Tax Rate (%): 30
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$
# Taxes: 2160.0$
# Net Income: 5040.0$

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Choose numerical operator: ")

if op == "+":
    res = num1 + num2
elif op == "-":
    res = num1 - num2
elif op == "*":
    res = num1 * num2
elif op == "/":
        res = num1 / num2
elif op == "//":
    res = num1 // num2
elif op == "**":
    res = num1 ** num2
elif op == "%":
    res = num1 % num2
else:
    print("Invalid operation")
    res = None

print(f"Result: {res}")
